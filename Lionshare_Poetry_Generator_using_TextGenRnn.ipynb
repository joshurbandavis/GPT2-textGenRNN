# %% [markdown]
# #  Lionshare Poetry Generator
#
# by Josh Davis based on a Collab Notebook by Max Wolfe
#
# This version of TextGenRNN is written in TensorFlow and intended to be run on Collab or similar VRAM GPUs. For a (poorly implemented) pyTorch version intended to be run locally, See Josh Urban Davis' GitHub.
#
# *Last updated: December 13th, 2018*
#
# Make sure you are running Google Chrome!

# %%
# !pip install -q textgenrnn
from google.colab import files
from textgenrnn import textgenrnn
from datetime import datetime
import os
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Set the textgenrnn model configuration here: the default parameters here give good results for most workflows.
#
# If you are using an input file where documents are line-delimited, make sure to set `line_delimited` to `True`.

# %%
model_cfg = {
    'word_level': True,   # set to True if want to train a word-level model (requires more data and smaller max_length)
    'rnn_size': 128,   # number of LSTM cells of each layer (128/256 recommended)
    'rnn_layers': 3,   # number of LSTM layers (>=2 recommended)
    'rnn_bidirectional': False,   # consider text both forwards and backward, can give a training boost
    'max_length': 5,   # number of tokens to consider before predicting the next (20-40 for characters, 5-10 for words recommended)
    'max_words': 200000,   # maximum number of words to model; the rest will be ignored (word-level model only)
}

train_cfg = {
    'line_delimited': False,   # set to True if each text has its own line in the source file
    'num_epochs': 100,   # set higher to train the model for longer
    'gen_epochs': 20,   # generates sample text from model after given number of epochs
    'train_size': 0.8,   # proportion of input data to train on: setting < 1.0 limits model from learning perfectly
    'dropout': 0.2,   # ignore a random proportion of source tokens each epoch, allowing model to generalize better
    'validation': False,   # If train__size < 1.0, test on holdout dataset; will make overall training slower
    'is_csv': False   # set to True if file is a CSV exported from Excel/BigQuery/pandas
}

# %% [markdown]
# In the Colaboratory Notebook sidebar on the left of the screen, select *Files*. From there you can upload files:
#
# ![alt text](https://i.imgur.com/TGcZT4h.png)
#
# Upload **any text file** and update the file name in the cell below, then run the cell.

# %%
file_name = "mythology.txt"
model_name = 'mythology'   # change to set file name of resulting trained models/texts

# %% [markdown]
# The next cell will start the actual training. And thanks to the power of Keras's CuDNN layers, training is super-fast when compared to CPU training on a local machine!
#
# Ideally, you want a training loss less than `1.0` in order for the model to create sensible text consistently.

# %%
textgen = textgenrnn(name=model_name)

train_function = textgen.train_from_file if train_cfg['line_delimited'] else textgen.train_from_largetext_file

train_function(
    file_path=file_name,
    new_model=True,
    num_epochs=train_cfg['num_epochs'],
    gen_epochs=train_cfg['gen_epochs'],
    batch_size=1024,
    train_size=train_cfg['train_size'],
    dropout=train_cfg['dropout'],
    validation=train_cfg['validation'],
    is_csv=train_cfg['is_csv'],
    rnn_layers=model_cfg['rnn_layers'],
    rnn_size=model_cfg['rnn_size'],
    rnn_bidirectional=model_cfg['rnn_bidirectional'],
    max_length=model_cfg['max_length'],
    dim_embeddings=100,
    word_level=model_cfg['word_level'])
# Out:
# Training new model w/ 3-layer, 128-cell LSTMs
# Training on 123,864 word sequences.
# Epoch 1/100
# 120/120 [==============================] - 19s 158ms/step - loss: 6.2796
# Epoch 2/100
# 120/120 [==============================] - 16s 133ms/step - loss: 5.4177
# Epoch 3/100
# 120/120 [==============================] - 16s 134ms/step - loss: 4.9653
# Epoch 4/100
# 120/120 [==============================] - 16s 134ms/step - loss: 4.5785
# Epoch 5/100
# 120/120 [==============================] - 16s 134ms/step - loss: 4.2026
# Epoch 6/100
# 120/120 [==============================] - 16s 134ms/step - loss: 3.8378
# Epoch 7/100
# 120/120 [==============================] - 16s 134ms/step - loss: 3.4892
# Epoch 8/100
# 120/120 [==============================] - 16s 134ms/step - loss: 3.1731
# Epoch 9/100
# 120/120 [==============================] - 16s 133ms/step - loss: 2.8906
# Epoch 10/100
# 120/120 [==============================] - 16s 134ms/step - loss: 2.6466
# Epoch 11/100
# 120/120 [==============================] - 16s 134ms/step - loss: 2.4296
# Epoch 12/100
# 120/120 [==============================] - 16s 134ms/step - loss: 2.2413
# Epoch 13/100
# 120/120 [==============================] - 16s 133ms/step - loss: 2.0796
# Epoch 14/100
# 120/120 [==============================] - 16s 134ms/step - loss: 1.9338
# Epoch 15/100
# 120/120 [==============================] - 16s 134ms/step - loss: 1.8054
# Epoch 16/100
# 120/120 [==============================] - 16s 131ms/step - loss: 1.6885
# Epoch 17/100
# 120/120 [==============================] - 16s 134ms/step - loss: 1.5880
# Epoch 18/100
# 120/120 [==============================] - 16s 133ms/step - loss: 1.4983
# Epoch 19/100
# 120/120 [==============================] - 16s 133ms/step - loss: 1.4165
# Epoch 20/100
# 120/120 [==============================] - 16s 133ms/step - loss: 1.3396
# ####################
# Temperature: 0.2
# ####################
# vedas , the people assembled at the grove of mars ,
# and built the gorgon , and a voice urn in her own death , addressed her and
# having been returned to the
# land of orpheus and eurydice . at length he encountered hector , and he laid his
# better . he seemed ,
# and yet it is impossible ,
# who is no hope of classical
# conqueror . the first is allowed the
# privilege of armor , and
# found a pair of compasses . daedalus was so envious , his
# broad virgin , in his vulgar body ,
# and round him their pleased audience clap their
# concern , and of the birth of
# christ , and he would destroy him . he told them a vessel ' s sail ,
# to broad joy , and instructed him to
# an effect to come to
# enable him to the hunters . they
# were required to practise the story of ibycus in the palace , and neglected for the
# natives , from the present air ,
# as it was said , she attempted to marry
# crime .
#
#
# echo and narcissus
#
#  ulysses was quite one of his
# sister , and while he yearns for her , he yet rejoices in her
# absence . presently a mast ,
# and carried her breast . she started back , exclaiming , " if thou art indeed my father , and receive me to
# trust himself to the waves , and bewailing
# off , and was propitious , the
# cause of the remains of ancient persians :
#
#  " what soil the gods , "
#
#
#
#  " they hesitate , and is the
# personification of the destroying principle . though the third
# named , he made his feet to a european shore , where he became a lookers -
# wood - - - - guest ; and at the
# sight of his armor glittering through the head of ivory .
#
#  the leader of the people and
# ascended it , and then
# weeps to whereat helen , having no oracle from
# you . i will make you whispering to us , and when take
# a care of some time of
# men . the inhabitants of
# flutes was heard and the odor of fragrant wine and a tree .
# months rolled away from the enjoyment of pleasant intercourse , and
# it was not to be envied the
# man , as he dragged his way to
# trail the city , the
# king of silvia , the whom ,
# just sovereign , and gave
# him to yield him , and to be obliged to the use of the
# collection .
#
#  the frieze of the parthenon , executed under the supervision of
# the zend books is of the most celebrated
# of the avatars of greek ,
# and in the very form of the gods ,
# and therefore , each claimed to him . when she mildly
# remonstrated , " for the trojans , i
# die , and my love - strings shall
# ask nought that your fate shall be
# changed . one of them , however ,
# happening to see the swarm of bees , and lost all
# occasions endangered his eyes to a rope
# he had
#
# and the cheek were too much to
# meet them and his limbs , and
# patroclus , as it gushed from the chasm of the
# king , and he repeated his
# former , if not the enemies of the
# world , represents a youth in the attitude
# of the attempts of fable of so many a god . "
#
#
# the sibyl
#
#  " it was nothing left of her own affairs at last , and invoked one of the
# greeks suspended himself in his arms , and hastened to the forge , and the physician , and the briton felt that he should show escape the
# fatal being now be kept
# by the kingdom of colchis .
# she was characterized by grave and dignified beauty , and freedom
# of any transient expression , in spite of the
# earliest days , but thialfi saw no
# better than it . thor then gave him his
# daughter , in his lays of ancient rome , thus alludes to the incident :
#
#  " - - - - sweet europa ' s mystic
# temple , they were favorably had married .
#
#  " but when the first bold men ? who are you doing with me ? what is " " said she , " shall i hope you to look ,
# who thus a present prince to
# the disc shore , and when she had intrusted to the
# keeping of the daughters of her son .
#
#  " the tall masts quivered as the mode of woman , the houses and seducer of
#
#  the gods of amalthea and
# fell by his hands , and neglected to
#
# ####################
# Temperature: 0.5
# ####################
#
#  at the earliest of the island , encouraged by the onward still had taken the castalian
# supreme god , and , they
# were inviolable and saw .
#
#
# triton and the chimaera , is the soul of the gods ,
# rather those of the greeks , especially
# were the people , by whom they were , and people
# to be bound . they
# were required to practise the strait of apollo and the
# dying day , and all eyes towards the
# air , and all they grew a game of quoits together ,
# described the mountain .
#
#  " the blindness " the
# gods here also a present blow ,
# though perhaps the splendor of those things ,
# groaned , and made his
# daughter of her daughter , whose
# name was the name of jupiter , the
# father of the gods , startled with all these words thor , and then i
# looked for my love .
# i will forget them so much to be pleaded
# with it he would have
# sprung his sword and turned to
# the smallest and coast . safe , the rivers , and virgil , who
# had no respect for the city . this is
# seized as the source of a groan . but chance the heavenly help ,
# and heroes trembled in the cave .
#
#  the sibyl then warned him that it should be taken of the
# legend ' s son , every side
# of the city . the
# gods were struck their ardor to the field , and told them to the story of
# orestes : the old king ,
#
# s island ,
# and rushed upon it , returned from the shore , and
# was prevailed on a statue of by
# the peplus or entire of
# corinth . when he saw
# the cock and tail .
# all this abuse , a victim to the
# monster , and the maiden
# had done , whatever had i know
# that he had been directed to
# attack , and , forgetting his contending armies ' the journey brought the way to sibyl . "
#
#
#
#  chapter xxix
#
#  modern monsters : the phoenix basilisk unicorn
# jupiter . the town , being told
# them , the daughter of maidens , beauty of troy , and
# juno turnus , one of his rutulians , he braced himself to the charm of his
# shoulders , and the dry fringe of the garment ,
# as mercury ' s poem on the opposite shore the groans , and compelled them out . they
# had taken out of the trojan
# flocks and returned with him . at length he encountered hector . at this he reverted to the present , and
# the apollo went joyfully down to sleep , but here they were
# exposed to their brows .
#
#  the princess approached to the bank . the attitude
# of all the stars .
#
#  the shepherd , the earnest of
# the greek being consulted by the
# greek cities , and bore them in
# disturbing the trojan war .
#
#
# daedalus
#
#  camilla , the god of the infernal regions , the
# red house of the country .
#
#  when they had recovered ,
# and the
#
# ,
# ulysses and landed on his men , carrying
# with them a treasures of sichaeus . on arriving at the spot where
# osiris stood over the spears of
# orestes : - - " - - , " the eternal - ,
# " not , the crown of the goddess ,
# the struggle , of which they had many
# temples or sacred to us of the
# roman in the world .
#
#  our readers will some have cost to be the sound of his charming living ,
# and the trunk of the
# crime .
#
#
# echo and narcissus
#
#  ulysses clung , and at last the invaders were
# deemed to others . the
# purple and soft , as a
# very precious wood . the two friends thus lost all the same
# . " she answered , " "
#
#  the basilisks could render the place of
# the winds , a earnest sun , and while he was absent and
# taught him , then now he
# loved the journey . the god , venus pale
# and the sound of the scourge , the creaking of the goddess , and returned to mycenae .
#
#  the young prince
# and mystic , and possesses three , celibacy , in the
# place in which he might know
# that the sun was not , reeking
# with the wound , and
# hastened to go with him ,
# as he repulsed by the former classes of those springs and persons of them . there are some
# vestiges of tombs on her , and stretched out her arms to her new - born race , and
# she
#
# ####################
# Temperature: 1.0
# ####################
# will come
# down to sail from the city , should rather have another shepherd who would attack him out of nessus . the flocks were originally near the spheres :
#
#  " what soil the - - headed . and
# often presented herself to the bank .
#
#  then next placed him in a year on a group ,
# in flashes of crimson ;
# one of the heavenly thrym had a second lion ' s teeth , and died by the corpse aside the solemn house of
# his mother , to seek his daughter of situation , but in the trojan war , and the
# legends and fabulous traditions relating to sailors of the victory . the following is by swift this age . of the god make the same power
# of a animal , whose kind was but only beautiful
# the spirit , the goddess of the underworld , erected to tellus of the universe , says ,
#
#  " when ajax strives to work , but this was real
# person , and inquired of danger at her
# dream to be a son of diana , it was called by a
# water , composed a lot form to the olympian mount
# which represents aeneas ' s only ; sending
# forth her licking an agate neck , here went on by plain , and
# taking his rend it .
#
#  perseus , continuing his flight , apollo ,
# the daughter of odin , beheld in his giving
# way she should have clung to pieces sybaris , venus ;
# all the voice who made
# received of sight . she
# answered , " icarus
# thou who can be
#
# apis , the eternal . schiller .
# at this perseus was the river - flowers
# of the deep and greek art was that marked with shaking
# these relish , and after poets
# god , build us and proserpine . " the
# following lines are the gods of those who made a of
# vulcan , or hurled it
# chiefly with it was said to known . "
#
#  pythagoras is only no more account
# for light and skill with her voice in a city to be given by previous
# the poets , assumed thy
# name , but it
# is remarkable for electra ; whereupon
# the authority who wholly having on one of the first became to be regarded as a representative of all , and although in his state . daedalus thus castor and pollux
# ovid under both sprang . the
# man then grown to apollo , and said , " here , " the wind called the earth ,
# waiting at home , and look
# down ascended , exclaiming , and my friend will not will
# forget them , except for and life , would have seen it
# brought to receive . the sons of virgins , and men thus of jove ,
#
#  " the king of ancient egypt consist of celestial , terrestrial ,
# said she , " here that " i ride help to get back the lance , the
# east brawler , and discovered the old body , and yoked it to a band of temple ,
# avenging " who are anything learned , now the wind in heaven . penelope , the queen , must shade down ,
# whatever might find
#
# sometimes streaming . after the feast of nine immortality with their love only
# till they gave an ash - shield
# the following is the lamentation of antigone ;
# but suddenly , the custom a summit and the house and the horn of a bull among the
# small still must be permitted to weep when they are kept away the
# anger of his chase , and bore him ,
# his limbs , the dreadful lips of stone , the
# eternal divinity . bellerophon from the
# hand , and when pomona , a good poet of his compositions ,
# but under this boy by the sand . it was too late ,
# that they should be perfectly
# perfect through the ground , and some holding on the right
# and they offered herself on to the field , and told them the wound , whence they were , and monsters a graceful grove , and the crop of both
# material was the sisters of osiris , king of sparta , make
# them to a young king . the other writers , that would
# not stand that leads , who inhabited his city was carried upon a golden greek grove . " these people from she
# closed in his breast a
# flower , sent him you
# by his hair , as having vented her art of her silken ringlets into egypt , but all they ever ;
# erisichthon to try him , and then rose yielded .
# at a fountain , sending him clear and crystal waters . the
# goddess of sappho commonly alluded to to horus or struck , and that it had been accepted
# in consequence . sometimes no statue
#
# Epoch 21/100
# 120/120 [==============================] - 15s 122ms/step - loss: 1.2745
# Epoch 22/100
# 120/120 [==============================] - 16s 131ms/step - loss: 1.2121
# Epoch 23/100
# 120/120 [==============================] - 16s 132ms/step - loss: 1.1568
# Epoch 24/100
# 120/120 [==============================] - 16s 133ms/step - loss: 1.1089
# Epoch 25/100
# 120/120 [==============================] - 16s 133ms/step - loss: 1.0587
# Epoch 26/100
# 120/120 [==============================] - 16s 134ms/step - loss: 1.0153
# Epoch 27/100
# 120/120 [==============================] - 16s 133ms/step - loss: 0.9768
# Epoch 28/100
# 120/120 [==============================] - 16s 133ms/step - loss: 0.9376
# Epoch 29/100
# 120/120 [==============================] - 16s 133ms/step - loss: 0.9029
# Epoch 30/100
# 120/120 [==============================] - 16s 133ms/step - loss: 0.8663
# Epoch 31/100
# 120/120 [==============================] - 16s 133ms/step - loss: 0.8377
# Epoch 32/100
# 120/120 [==============================] - 16s 134ms/step - loss: 0.8093
# Epoch 33/100
# 120/120 [==============================] - 16s 133ms/step - loss: 0.7815
# Epoch 34/100
# 120/120 [==============================] - 16s 133ms/step - loss: 0.7542
# Epoch 35/100
# 120/120 [==============================] - 16s 131ms/step - loss: 0.7290
# Epoch 36/100
# 120/120 [==============================] - 16s 133ms/step - loss: 0.7049
# Epoch 37/100
# 120/120 [==============================] - 16s 133ms/step - loss: 0.6840
# Epoch 38/100
# 120/120 [==============================] - 16s 133ms/step - loss: 0.6645
# Epoch 39/100
# 120/120 [==============================] - 16s 133ms/step - loss: 0.6439
# Epoch 40/100
# 120/120 [==============================] - 16s 133ms/step - loss: 0.6237
# ####################
# Temperature: 0.2
# ####################
#
#  the following lines are in the earthly beauty , see ,
# in a poisoned entrails . the
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
#
# , is in the same
# for the king of the phaeacians , had no
# aid to stand in the form of a serpent . i have a
# hammer . he found the
# hospitable to breast and limbs to make delicious apples . his
# hand was cruel to represent the
# mythology of the nation has been had been left behind by
# the ships . they found
# them aboard with all haste to these words : " spare me , i would refuse thee to be . "
#
#
# the camenae
#
#  by the name of phoenix , after disappearing for a series of ages and
# subject to my retirement .
#
#
#
#  chapter xiv
#
#  bacchus we must picture to this , in the louvre a temple of the characters , were always been by the number of grecian
# famous in the greek or .
#
#  " round about the caldron go to the
# meat that they had no
# fields or flocks to leave me to so baldur
# out , while he was a
# work of the hind which the
# gods who were about to be sacrificed .
# ascertaining from the sixth century
# before christ , he was
# sent to the throne and his
# companions in the palace , which washes on
# food or bed , but the mother and boy . the sound of
# flutes was heard and the odor of fragrant wine spread all around .
#
#  the sibyl then returned to take him a cup of ambrosia o , so said , and this also learned
# is from the vedas . these
# were in those of their
#
#
#  this unseemly the valkyrior are a temple
# of a butterfly , alone or with him , and
# built a bridge , and
# hurling the storm - tossed sea .
#
#  blest leucothea , with me ! i would not have
# suffered thee to enter this time , know the
# grandchildren . " then the hostility of
# tartarus descended , so to the
# giant , and the son of attalus . figures of
# earlier than the poet has been far as often found her on his shoulders who into the midst . being
# they made a question supposed to have failed in
# fidelity to their employers . here was one who had fallen ,
# for a cloud which was allowed to the person of affairs . the number were not asked
# leave her body , with a club on her the side of heaven . hercules and all things looked , in india , carefully no illustration of
# himself , is dark to look the last symphony
#
# . thus thus tells this statue was a work of
# diana and some other like the rule of war .
#
#  mr . longfellow in his drinking song thus you do the
# children , in the flower of the blind - field falling , putting an oracle of venus ,
# ai , king , for if he had so said to seek our knowledge . of the figure is
# as i see no would do
# you ? the gates of
# stream , and beside the starry world , and , lay in my head :
#
#  " as when alcides ( alcides was a mysterious wars between the
# power of the exhalations , , a divine inspiration . the fact was
# speedily fell the other with his uncle . he announced himself by his own kingdom ,
# to be a slight wound , a second
# very rim of one country and the head of wild
# art . " aeneas , indignant
# at the same who
# slain , my brothers ! even the poor doubters , uncertain of them so were kept in their poetry of
# duty , a
# state of the two sons of nestor performed
# prodigies of valor . the king and other
# had choice some idea me , a light made
# of the earth , which is flying old , as its face , the
# body of all fire , younger attributed to
# the general camp .
#
#  the next morning at the
# utgard - wild , " there are not turn some
# happy in the allegory of
# this was the aphrodite in a religious
# establishment of the greek triad was
#
#
#  the following statement as to these deities and the names of
# bacchus , is found immortal food to venus ' s caves and hue were brought back the leaves and
# entered the neck with a other
# blow . it is as a wild
# chance upon the rock .
#
#  cassiopeia was a dead . under the work of aeneas . finally they were celebrated
# osiris , for the olympian zeus , and called the goddess .
# her parents , called if one of the
# head is of a golden
# spring . here the mind was lost , and the more - in common encounter on the leaves and
# were held , their ships at music ,
# would have the roar of aeneas ,
# saying she turned her and seeing this view , was only orion , who had assumed to make his
# guilt of the amazons , and returned to pass the giant ' s
# promise to the new fate of forms
# the gods of high - minded
# back and her eyes to
# pride . aeneas had warned him out of the body . myron carried the
# of representation so far as if in its
# age which minos , king of his sorrows , had
# made a pair of compasses . daedalus was so envious that his
# tree would not love , then he went to the four
# water , called the flower of the step - nymph , was of dryope and her face . she held him to
# the plough and safer just
# eating his only repose . "
#
#
#
#  chapter xiv
#
#  bacchus we can withstand jupiter ,
#
# Epoch 41/100
# 120/120 [==============================] - 15s 122ms/step - loss: 0.6093
# Epoch 42/100
# 120/120 [==============================] - 16s 132ms/step - loss: 0.5913
# Epoch 43/100
# 120/120 [==============================] - 16s 133ms/step - loss: 0.5714
# Epoch 44/100
# 120/120 [==============================] - 16s 134ms/step - loss: 0.5587
# Epoch 45/100
# 120/120 [==============================] - 16s 133ms/step - loss: 0.5414
# Epoch 46/100
# 120/120 [==============================] - 16s 132ms/step - loss: 0.5220
# Epoch 47/100
# 120/120 [==============================] - 16s 133ms/step - loss: 0.5151
# Epoch 48/100
# 120/120 [==============================] - 16s 133ms/step - loss: 0.5030
# Epoch 49/100
# 120/120 [==============================] - 16s 133ms/step - loss: 0.4873
# Epoch 50/100
# 120/120 [==============================] - 16s 133ms/step - loss: 0.4729
# Epoch 51/100
# 120/120 [==============================] - 16s 133ms/step - loss: 0.4598
# Epoch 52/100
# 120/120 [==============================] - 16s 133ms/step - loss: 0.4541
# Epoch 53/100
# 120/120 [==============================] - 16s 132ms/step - loss: 0.4418
# Epoch 54/100
# 120/120 [==============================] - 16s 133ms/step - loss: 0.4319
# Epoch 55/100
# 120/120 [==============================] - 16s 133ms/step - loss: 0.4219
# Epoch 56/100
# 120/120 [==============================] - 16s 133ms/step - loss: 0.4116
# Epoch 57/100
# 120/120 [==============================] - 16s 133ms/step - loss: 0.4055
# Epoch 58/100
# 120/120 [==============================] - 16s 134ms/step - loss: 0.3930
# Epoch 59/100
# 120/120 [==============================] - 16s 133ms/step - loss: 0.3804
# Epoch 60/100
# 120/120 [==============================] - 16s 133ms/step - loss: 0.
# its neck and come , his brother
#
# a goddess of
# display , and died this from
# the day are the king result carried his
# chariot to the east . when a time the
# slave , a cold look , and hid
# brushed it . yet this away , the gift of my father . " galatea then friends to have come down upon
# such love - men not without
# their thoughts . he told them to
# the of the religion which preceded this animal is his friend and one of the golden fleece , but chiron was king ' s mother and get
# away to the first , his they were carried away .
# stretching out their assistance to aeneas , like the thought of the
# gods , now it was before that he
# embarked , they gave favorably were sent to have fallen into them , and he held out
# asleep , and on their royal
# the shores wave . the
# gods made his escape by
# it , were the son of osiris and
# turnus .
#
#  thinks he sacred round .
# " have recognized a golden place where she was the
# full of life and came . on one side was that of one can
# which may be leave to myrrh , and finished was of his
# wound and possession of this prayer .
#
#
# neptune
#
#  neptune was the son of that thetis at the place of achilles and has
# become proverbial . electra frequently reminded her brother hy
# messengers of the duty of avenging his " father made up , " said utgard - loki , " how it is not ' s doing at the
#
# Epoch 61/100
# 120/120 [==============================] - 15s 122ms/step - loss: 0.3667
# Epoch 62/100
# 120/120 [==============================] - 16s 131ms/step - loss: 0.3602
# Epoch 63/100
# 120/120 [==============================] - 16s 132ms/step - loss: 0.3496
# Epoch 64/100
# 120/120 [==============================] - 16s 133ms/step - loss: 0.3420
# Epoch 65/100
# 120/120 [==============================] - 16s 133ms/step - loss: 0.3370
# Epoch 66/100
# 120/120 [==============================] - 16s 133ms/step - loss: 0.3291
# Epoch 67/100
# 120/120 [==============================] - 16s 133ms/step - loss: 0.3256
# Epoch 68/100
# 120/120 [==============================] - 16s 133ms/step - loss: 0.3214
# Epoch 69/100
# 120/120 [==============================] - 16s 134ms/step - loss: 0.3101
# Epoch 70/100
# 120/120 [==============================] - 16s 134ms/step - loss: 0.3065
# Epoch 71/100
# 120/120 [==============================] - 16s 134ms/step - loss: 0.3005
# Epoch 72/100
# 120/120 [==============================] - 16s 133ms/step - loss: 0.2951
# Epoch 73/100
# 120/120 [==============================] - 16s 134ms/step - loss: 0.2880
# Epoch 74/100
# 120/120 [==============================] - 16s 134ms/step - loss: 0.2868
# Epoch 75/100
# 120/120 [==============================] - 16s 133ms/step - loss: 0.2781
# Epoch 76/100
# 120/120 [==============================] - 16s 133ms/step - loss: 0.2740
# Epoch 77/100
# 120/120 [==============================] - 16s 133ms/step - loss: 0.2686
# Epoch 78/100
# 120/120 [==============================] - 16s 134ms/step - loss: 0.2645
# Epoch 79/100
# 120/120 [==============================] - 16s 133ms/step - loss: 0.2576
# Epoch 80/100
# 120/120 [==============================] - 16s 134ms/step - loss: 0.2557
# ####################
# Temperature: 0.2
# ####################
# a vessel filled with armed warriors floated on the stream of the
# tiber , the greek stories and conceptions of characters are
# and praxiteles are some individuals of the body . before i will find the woolly gold sticking to
# the bushes and the trunks of the air . "
#
#  the following legend :
#
#  " there too the goddess loves in stone , and fills their black and blood ; but the
# happy in the kingdom . at last the satyrs was
# a statue of apollo , was
# in the shut we must be
# conveyed them , flew to the
# palace and of the gods . pallas , the son of
# achilles , rushed into wounded , , with the sun and moon , and not therefore
# to be eclipsed in a symbol of a
# monster with trees , and
# scrupled to go to him her , and threw his head and his lyre into the
# river , a rattling given the form of to
# a pile , with a
# vine body , to which they had hung up , they found the
# men of the crew summoned their powers .
#
#  byron , in his ode to napoleon bonaparte , alludes to the story of
# orestes : " - - - he guest as
# the argo , and it was the business of its
# earlier place . they loved
# the argonauts and a bull . the nymphs
# gave him , and said he '
# the other , is a
# statue of the artistic . this
# the successfully group : - like other , the other lines of greece ,
#
#
# hear the form of
# divine , in youth , and
# he thrust him through with his sword .
#
#  this story , entitled skirnir for , and the one immediately
# preceding it , thrym ' s , will be found in poem ; the roman writers to add
# the story of theseus is interpreted in a apollo ,
# and sometimes enclosed between horns and the children to have been executed entirely by them ,
# father , " said he , " in that
# these lines of the figures of
# polycleitos . he descended into his hands , and the monster was the
# dominant faith of the east , till the rise of the power
# and the conquest of persia by alexander the great . he was
# the goddess of icarius , and loved by
# the country where you may be
# done . " apis , " says , " at the same time
# she touched him , and was at
# last
#
# a vessel filled ; and
# apparently in the works of the
# ancient meeting , which is
# that he should be like cupid as
# long as the head has gained by the substitution . the spear
# wordsworth , the roman naturalist of fire , for the
# disease yet have been directed
# that he should be like cupid as he
# thor would defend the entrance into it . it was formally
# to destroy me , and would have
# been for the stranger .
#
#  when the solemnities were ended all moved towards the city . the
# king surround him , he took a beautiful man of humble parentage , who saw and loved
# anaxarete , and old , could not bear the sight that he
# almost forgot to wave his wings i
# require for my name " o latest
# things , and some , who had assumed to give his
# fate .
#
#
#
#  chapter xxviii
#
#  origin of mythology statues of gods and goddesses poets of
# mythology
#
#  having reached the directions she
# became due arms to the east , when he did he said he , " and i hope you will not despise . so at the same time , and maidens ,
# thus of the king make
# his raised the high and
# admiration of the phaeacians , to which the
# time never drove out their
# body . one day the zeus , being of old , half - dark
# that they wove , several
# things , that the western was the suffering , but the
# gods in which gratitude sought the story of the
# gods ,
#
# ####################
# Temperature: 1.0
# ####################
#
#
# orion
#
#  orion was the son of neptune . he was a handsome giant , a
# ruler of the rock , and in which
# they were washing among the country of other
# and seven they had planted , that are had no work to be
# the personification of the gods .
#
#  by this tower upon him , and made a
# short , of which a wild beast sprang from a
# conclusion , of his poem , the has
# translated , at thy heavenly destruction and went ,
# and she conceived the idea of retiring
# a golden distaff . that , i am
# too that your curiosity had destined to thy father , again ,
# jupiter at the greater hand . the greeks went joyfully upon it .
#
#  in the poems of campbell will be found a translation of one of the
# neighboring cities , but his people drove him out . with him all wound , without
# aid to exterior has made thy
# break in the large history of canachos , the city , and the
# sound was as the sound of a groan . the servants opened the door of the
# head and the of his
# return and others with dwellings or
# time , she was directed
# their own work . these are the
# gave wisdom before troy ,
# which , the boy was said to fall , perseus became it . when he has been able to see at you . let it would not leave me
# where any other remains of the
# greeks ) to take rank in the order of their birth , the
# only
#
#
#  " back comes the chief in triumph
# who had done here , the name is from the
# central lines of beings that they
# were did to be ,
# and these of were flock at the first
# insolent the bathed she let them
# themselves ; and all the
# ocean , the rattling , and beware them
# all that air was no more than a nymph lotis .
#
#
#
#  chapter xxi
# the highest religion of the
# egyptians carried to in the trunks of worshippers . hero .
#
#  young , in the night thoughts , alludes to the sibyl
# how him that it was
# a corrupt tradition has been a bit to see how there , the gods and were to
# loved , and soon shall be tried to her
# it in the earth , far
# off the odin ' s
# hall , where polydectes and his guests
# after the festival of these , had in her the
# body of a man . it sprang on the
# service of admetus of the
# daughter of a , of cruelty
# in this place as it would have
# fallen . then i succeed , the
# face of the earth . it
# represents a punishment of your
# mountain has been so a
# first time , they saw the
# men of his son faunus
# and that field were readily inferred , their bodies was one and
# had , if it was ,
# for by degrees , the other two
# of gods and men to whole
# universe .
#
#  the artist then lived to
# one of the original .
#
#
#  madness was one of his
# sons . " think how o mother , heard , , and able to find her assistance . if he was seized
# the giant and her .
# she is the husband of the tenth avatar , was a good of whom the man threw at hand
# to people by the sand .
#
#  yes , ' tis he ! although he perished ,
# still his sacred rites ; and of thessaly ,
# the prince of the time of his mountain had
# her escape from the original .
#
#  other aphrodites the first god is called me . "
#
#  euryalus
#
#  proud of the hero , and toward fire and his life . the first
# blood of the men . she dwelt in the temple
# erytheia . the third theory is those of which some admired the
# person , but by themselves is not
# thrown away , and the breath of his
# command the same time to take possession
# of the death , that enjoys the war -
# fire - horse to him . hercules was the mind of a very rock and the name
# of the sun . placing kedalion on his shoulders , orion proceeded
# to the east , and there meeting the master was at
# his father , and he held in his right hellenic (
# deeds ) of the war of the conquered
# tree . he shall i , but he might not be obliged to such to minos , who
# followed the building for the sibyl ,
# her sisters , devoured by their hands , but the priests . the test selected was shooting
#
# Epoch 81/100
# 120/120 [==============================] - 15s 122ms/step - loss: 0.2503
# Epoch 82/100
# 120/120 [==============================] - 16s 131ms/step - loss: 0.2460
# Epoch 83/100
# 120/120 [==============================] - 16s 132ms/step - loss: 0.2410
# Epoch 84/100
# 120/120 [==============================] - 16s 133ms/step - loss: 0.2356
# Epoch 85/100
# 120/120 [==============================] - 16s 133ms/step - loss: 0.2334
# Epoch 86/100
# 120/120 [==============================] - 16s 133ms/step - loss: 0.2285
# Epoch 87/100
# 120/120 [==============================] - 16s 132ms/step - loss: 0.2259
# Epoch 88/100
# 120/120 [==============================] - 16s 133ms/step - loss: 0.2232
# Epoch 89/100
# 120/120 [==============================] - 16s 133ms/step - loss: 0.2167
# Epoch 90/100
# 120/120 [==============================] - 16s 133ms/step - loss: 0.2140
# Epoch 91/100
# 120/120 [==============================] - 16s 131ms/step - loss: 0.2139
# Epoch 92/100
# 120/120 [==============================] - 16s 131ms/step - loss: 0.2137
# Epoch 93/100
# 120/120 [==============================] - 16s 132ms/step - loss: 0.2066
# Epoch 94/100
# 120/120 [==============================] - 16s 134ms/step - loss: 0.2065
# Epoch 95/100
# 120/120 [==============================] - 16s 132ms/step - loss: 0.2039
# Epoch 96/100
# 120/120 [==============================] - 16s 132ms/step - loss: 0.2016
# Epoch 97/100
# 120/120 [==============================] - 16s 133ms/step - loss: 0.2007
# Epoch 98/100
# 120/120 [==============================] - 16s 134ms/step - loss: 0.1968
# Epoch 99/100
# 120/120 [==============================] - 16s 134ms/step - loss: 0.1946
# Epoch 100/100
# 120/120 [==============================] - 16s 133ms/step - loss: 0.1924
# ####################
# Temperature: 0.2
# ####################
#
#  osiris was isis . he
# struggled in the sound . a person was heard from
# his celestial .
#
#  but the strains of his body had drawn round him , but
# one dying , were about to be sent to destroy him . the hydra had nine heads , of
# his head , and he seemed to
# the natives from the city of the
# parent bird . but a people with these
# words , on the acropolis river at
# aeetes , so the , says were
# a controversy to to his father . if you have not
# than my worship ! " have you
# one of the other chiefs .
#
#  it was said that zephyrus ( the west - wind ) , who was also
# that the druids had not to be fixed in
# the heliotrope of southern france , but weed not a man in the flame . the people rushed
# from every side breathing may
# reach the statue of our
# youth , and with every returning spring revives the memory of
# his fate .
#
#  after this alfadur or time a enclosed only of the
# greek art .
#
#  agoracritos left behind him works at his
# bride to make a sovereign ' s father ,
# and calls her ghost ,
# forever , ever , ever lost !
# now with furies surrounded his
# breast . then , with a huge form and called by them ,
# and he repulsed her advances . " " have all things this power of the heavenly bodies in the
# earliest of the egyptians consisted of an extended polytheism
# represented by a
#
#
#  osiris was isis . hercules
# was deceived by my head . "
#
#
# the funeral of baldur
#
#  the spheres :
#
#  " they on his side
# leaning half raised , with ears .
# this i have found that
# pride , if otherwise was
# could touch . if torn away , another would succeed .
#
#  aeneas followed the directions he
# became due to age ' s abode .
# it was indeed the same
# time . he is handsome , and a
# triad was at a mercy of all whose
#
#  what was , yet no means of the wrong you
# have furnished for him without fear . perhaps and he was about to
# challenge the country of the cyclopes . the cyclopes
# were giants , who inhabited an island of which they were the only
# possessors . " take no chance so
# to raised the prize of
# and swam . cadmus threw his eyes on the grass , which they were the
# were of and importance in his
# wealth "
#
#
#
#  chapter
#
#  the death of icarus and told the proud of the
# trojans , besides all their power
# and supremacy . cupid
#
#  the giant observed that i may not touch you . but with this , absence , though i have not
# than myself , and if
# you will be then by
# the conquered appearance ; that he set the young man ' s life .
# then i have mortal wish to see to take her , and
# lay a more to be built
# and to the island of
#
#
#
#  " back comes the chief in triumph
# who had been the wise and perished ;
# now the island of the god .
# aesculapius was propitious , and on the return
# of the vessel to port , he transformed it into a rock , right
# opposite the mouth of the rocks . and
# soon as he could have been handed down
# from age to age by means of the memory alone . this is answered
# by ? " she added , " thou
# hast been death ' s hue on thee ; why then thou here on the
# way to hel ? "
#
#  " because i am blind , " answered , " so saying , he sprang into the deep
# sea . here it is not
# for the worship of bacchus or established in greece .
#
#  there is an allusion to camilla in those well - known lines
# of the earliest greeks the hero , he
# immediately the other ' s hands . the sea was so impressed , as the
# east , which visited the king and country , and was of
# with great his eternal birds ,
# wherever the two only were equally
# on her with human hands , but the
# happy in the kingdom . at last the satyrs was
# a ! " i am ,
# " i see ; " said he , " long expected and do i behold you after such
# perils past ? o my son
# how : " the virgin is destined for the bride of the dying monster ,
# and when she awoke he would not have
# but a partial triumph
#
# ####################
# Temperature: 0.5
# ####################
# , is in this statue from , the god of the infernal regions ; 4 . surya . the
# goddess who seems to bring to
# be the goddess of the music , and then in its
# former , of from them the ancient world .
#
#  the egyptian prince
# and minerva . mercury gave him her and
# love . she called them and
# she left him the same
# . this state is to
# the knowledge of the letters of the alphabet which were considered in the days of
# their skill the father of the roman
# day .
#
#  the first glow of pleasure and
# minerva . my children had been changed into egypt . the
# gods , after the spot
# still of their great already
# under the wheels , and the
# multitude , and it is now at
# his hair his wife .
#
#  among schiller ' s poem " cassandra were the or finding that it had not doubt it these from the goddesses . "
#
#  so saying , he lifted the axe , and the names seemed to have been
# to procure to him . he told her power , and to come her . opposite
# a lance , and soon
# she let him and let go
# into longer sight , the whole face of its
# purple fair is to the sight of which he was struck at the seat of the island . the sea was erected to
# the destinies of southern regions . but there is another branch
# of , superstitions a nymph that a grove ,
# after him her , soft wandering , poor
# assistance
#
#
#  " back comes the chief in triumph
# who had been had heard of
# the cave , and found
# all to be beaten , who swelled with envy of their now nor listen . then , " shall be your ruin . " terrified by this
# oracle , she fled the society of men , and from asia from the
# of , he is in his youthful his own . there a man had
# thrown , and a faithful
# height , and not lost to his island , where all the gods were slain , and finding it
# men to homer , or that of siva , ) of the great , is would have been
# for a wild , gleaming a goat , placed them of religious works were
# which for many had the
# company of the rest . when he has also
#
#
# stories are the brahmans of the gods , stem so as to a
# wallet , at one his giant , a beautiful
# woman , named the sculptors of our song are given of
# the portentous signs which followed . the skins of the second
# she found , she pierced through the roots , which had been loved by the priests and their
# attendants , and the winds are gold , and
# that which became attracted by the world by achilles , it must be
# supposed in the world which it would
# have reached some furnished for , they could not but wait till the morrow , she would
# procure for him a time when they offered to be slain .
#
#  " but should suspense permit the fatal way , and
# prevented his escape from the rest , he made and bore her on the sea - mother where the people assembled . they put
# to hide such blushes in the recesses of the woods . from that time
# forth she lived in caves and among mountain cliffs . her husband , who appeared
# manifestly and feasted among them when he offered sacrifices , a daughter of one cannot in
# care that no mortal even the
# sculptors ; the great seven ,
# as those of the most
# may have been ' somewhat
# hither and gift from your three ! "
#
#  thor replied of i felt my first cave ' deep
# feel it was in the
# year , it is more than this
# was necessary in great numbers . the mariners in these other chiefs ,
# their horses to the trojans ,
# to die with

# %% [markdown]
# You can download a large amount of generated text from your model with the cell below! Rerun the cell as many times as you want for even more text!

# %%
# this temperature schedule cycles between 1 very unexpected token, 1 unexpected token, 2 expected tokens, repeat.
# changing the temperature schedule can result in wildly different output!
temperature = [0.5,0.5,0.2,1.0]
prefix = None   # if you want each generated text to start with a given seed text

if train_cfg['line_delimited']:
  n = 1000
  max_gen_length = 60 if model_cfg['word_level'] else 300
else:
  n = 1
  max_gen_length = 2000 if model_cfg['word_level'] else 10000

timestring = datetime.now().strftime('%Y%m%d_%H%M%S')
gen_file = '{}_gentext_{}.txt'.format(model_name, timestring)

textgen.generate_to_file(gen_file,
                         temperature=temperature,
                         prefix=prefix,
                         n=n,
                         max_gen_length=max_gen_length)
files.download(gen_file)

# %% [markdown]
# You can download the weights and configuration files in the cell below, allowing you recreate the model on your own computer!

# %%
files.download('{}_weights.hdf5'.format(model_name))
files.download('{}_vocab.json'.format(model_name))
files.download('{}_config.json'.format(model_name))

# %% [markdown]
# To recreate the model on your own computer, after installing textgenrnn and TensorFlow, you can create a Python script with:
#
# ```
# from textgenrnn import textgenrnn
# textgen = textgenrnn(weights_path='colaboratory_weights.hdf5',
#                        vocab_path='colaboratory_vocab.json',
#                        config_path='colaboratory_config.json')
#
# textgen.generate_samples(max_gen_length=1000)
# textgen.generate_to_file('textgenrnn_texts.txt', max_gen_length=1000)
# ```
#
# Have fun with your new model! :)

# %% [markdown]
# # Etcetera
#
# If the model fails to load on a local machine due to a model-size-not-matching bug (common in >30MB weights), this is due to a file export bug from Colaboratory. To work around this issue, save the weights to Google Drive with the two cells below and download from there.

# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from google.colab import files
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
uploaded = drive.CreateFile({'title': '{}_weights.hdf5'.format(model_name)})
uploaded.SetContentFile('{}_weights.hdf5'.format(model_name))
uploaded.Upload()
print('Uploaded file with ID {}'.format(uploaded.get('id')))
# Out:
# Uploaded file with ID 1b6T6M32YnXs-c0NB-PEi6MhAdCuG7RHy

# %% [markdown]
# If the notebook has errors (e.g. GPU Sync Fail), force-kill the Colaboratory virtual machine and restart it with the command below:

# %%
# !kill -9 -1
